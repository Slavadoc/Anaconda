# %%
import pandas as pd

# %% [markdown]
# Series

# %%
a = pd.Series([4,6,8,9,10],index=['one', 'two', 'three', 'four', 'five'])
a
# Out:
# one       4
# two       6
# three     8
# four      9
# five     10
# dtype: int64

# %%
b = pd.Series(['one', 'two', 'three', 'four', 'five'])
b
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# 4     five
# dtype: object

# %%
a.values
# Out:
# array([ 4,  6,  8,  9, 10], dtype=int64)

# %%
a.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
a[3]
# Out:
# 9

# %%
a[2]
# Out:
# 8

# %% [markdown]
# ### DataFrame

# %% [markdown]
# Синтаксис создания:
# pandas.DataFrame(input_data, index)
# -	input_data: ввод в виде Dict, 2D массива NumPy, Series и т. д.
# -	index: значения индексов.

# %%
df = pd.DataFrame({
    'Age': [46, 34, 22, 65, 22],
    'Country': ['Russia','Belarussia','Kazahstan','Russia', 'Moldovia'],
    'Gender': ['Famale', 'Male', 'Famale','Male', 'Famale',]
})
df
# Out:
#    Age     Country  Gender
# 0   46      Russia  Famale
# 1   34  Belarussia    Male
# 2   22   Kazahstan  Famale
# 3   65      Russia    Male
# 4   22    Moldovia  Famale

# %%
df['Age']
# Out:
# 0    46
# 1    34
# 2    22
# 3    65
# 4    22
# Name: Age, dtype: int64

# %%
df.Country
# Out:
# 0        Russia
# 1    Belarussia
# 2     Kazahstan
# 3        Russia
# 4      Moldovia
# Name: Country, dtype: object

# %%
df[['Age',"Country"]]
# Out:
#    Age     Country
# 0   46      Russia
# 1   34  Belarussia
# 2   22   Kazahstan
# 3   65      Russia
# 4   22    Moldovia

# %%
df.columns
# Out:
# Index(['Age', 'Country', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df = pd.DataFrame({
    'Age': [46, 34, 22, 65, 22],
    'Country': ['Russia','Belarussia','Kazahstan','Russia', 'Moldovia'],
    'Gender': ['Famale', 'Male', 'Famale','Male', 'Famale',]
}, index = [5, 4, 6,3, 2])
df
# Out:
#    Age     Country  Gender
# 5   46      Russia  Famale
# 4   34  Belarussia    Male
# 6   22   Kazahstan  Famale
# 3   65      Russia    Male
# 2   22    Moldovia  Famale

# %%
df.index = [101, 102, 103, 104, 105]
df
# Out:
#      Age     Country  Gender
# 101   46      Russia  Famale
# 102   34  Belarussia    Male
# 103   22   Kazahstan  Famale
# 104   65      Russia    Male
# 105   22    Moldovia  Famale

# %% [markdown]
# ### Считывание данных

# %%
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df = pd.read_csv('Churn_Modelling.csv',header = 1)
df
# Out:
#           1  15634602   Hargrave  619   France  Female  42   2          0  \
# 0         2  15647311       Hill  608    Spain  Female  41   1   83807.86
# 1         3  15619304       Onio  502   France  Female  42   8  159660.80
# 2         4  15701354       Boni  699   France  Female  39   1       0.00
# 3         5  15737888   Mitchell  850    Spain  Female  43   2  125510.82
# 4         6  15574012        Chu  645    Spain    Male  44   8  113755.78
# ...     ...       ...        ...  ...      ...     ...  ..  ..        ...
# 9994   9996  15606229   Obijiaku  771   France    Male  39   5       0.00
# 9995   9997  15569892  Johnstone  516   France    Male  35  10   57369.61
# 9996   9998  15584532        Liu  709   France  Female  36   7       0.00
# 9997   9999  15682355  Sabbatini  772  Germany    Male  42   3   75075.31
# 9998  10000  15628319     Walker  792   France  Female  28   4  130142.79
#
#       1.1  1.2  1.3  101348.88  1.4
# 0       1    0    1  112542.58    0
# 1       3    1    0  113931.57    1
# 2       2    0    0   93826.63    0
# 3       1    1    1   79084.10    0
# 4       2    1    0  149756.71    1
# ...   ...  ...  ...        ...  ...
# 9994    2    1    0   96270.64    0
# 9995    1    1    1  101699.77    0
# 9996    1    0    1   42085.58    1
# 9997    2    1    0   92888.52    1
# 9998    1    1    0   38190.78    0
#
# [9999 rows x 14 columns]

# %%
df = pd.read_csv('Churn_Modelling.csv', sep=';')
df
# Out:
#      RowNumber,CustomerId,Surname,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Exited
# 0     1,15634602,Hargrave,619,France,Female,42,2,0,1...
# 1     2,15647311,Hill,608,Spain,Female,41,1,83807.86...
# 2     3,15619304,Onio,502,France,Female,42,8,159660....
# 3     4,15701354,Boni,699,France,Female,39,1,0,2,0,0...
# 4     5,15737888,Mitchell,850,Spain,Female,43,2,1255...
# ...                                                 ...
# 9995  9996,15606229,Obijiaku,771,France,Male,39,5,0,...
# 9996  9997,15569892,Johnstone,516,France,Male,35,10,...
# 9997  9998,15584532,Liu,709,France,Female,36,7,0,1,0...
# 9998  9999,15682355,Sabbatini,772,Germany,Male,42,3,...
# 9999  10000,15628319,Walker,792,France,Female,28,4,1...
#
# [10000 rows x 1 columns]

# %%
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
df.tail(3)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.sample(frac=1
         )
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 1826       1827    15573893      Barry          569   Germany    Male   25
# 9486       9487    15605130   Seccombe          753    France    Male   32
# 1887       1888    15680918    Freeman          613     Spain    Male   34
# 292         293    15655774      Booth          583    France    Male   27
# 4030       4031    15808760     Evseev          603     Spain  Female   42
# ...         ...         ...        ...          ...       ...     ...  ...
# 6731       6732    15643826      McKay          503    France    Male   32
# 6933       6934    15679961   Davidson          708     Spain    Male   46
# 1390       1391    15727281  Macintyre          653    France  Female   27
# 5382       5383    15589296      Brown          724    France  Female   40
# 5495       5496    15601387        Yen          721    France    Male   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1826       9  173459.45              2          1               1
# 9486       6  177729.13              1          1               1
# 1887       8  117300.02              1          1               0
# 292        7       0.00              2          1               0
# 4030       6       0.00              1          1               1
# ...      ...        ...            ...        ...             ...
# 6731       4       0.00              2          1               1
# 6933       7   68799.72              1          1               1
# 1390       9       0.00              2          1               0
# 5382       6  110054.45              1          1               1
# 5495      10       0.00              2          1               0
#
#       EstimatedSalary  Exited
# 1826         44381.06       0
# 9486        161642.08       0
# 1887        139410.08       0
# 292          51285.49       0
# 4030         90437.87       0
# ...               ...     ...
# 6731        153036.97       0
# 6933         39704.14       0
# 1390         96429.29       0
# 5382         86950.72       0
# 5495         71594.26       0
#
# [10000 rows x 14 columns]

# %%
df.sample(frac=1)
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 5455       5456    15726855         Oliver          805   Germany  Female
# 7769       7770    15757473  Chukwujamuike          766    France  Female
# 6821       6822    15704209          Noble          802    France  Female
# 11           12    15737173        Andrews          497     Spain    Male
# 355         356    15739438           Reed          539    France    Male
# ...         ...         ...            ...          ...       ...     ...
# 1462       1463    15566211            Hsu          616   Germany  Female
# 4721       4722    15695034       Christie          757    France  Female
# 9954       9955    15739850       Trentino          645    France    Male
# 445         446    15803406           Ross          748    France  Female
# 6619       6620    15586517        Toscano          647    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5455   45       9  116585.97              1          1               0
# 7769   27       7  158786.67              2          0               1
# 6821   39       7  120145.96              2          0               1
# 11     24       3       0.00              2          1               0
# 355    30       0       0.00              2          1               0
# ...   ...     ...        ...            ...        ...             ...
# 1462   41       1  103560.57              1          1               0
# 4721   44       4  123322.15              1          1               0
# 9954   45       6  155417.61              1          0               1
# 445    26       1   77780.29              1          0               1
# 6619   32       5   97041.16              1          1               1
#
#       EstimatedSalary  Exited
# 5455        189428.75       1
# 7769         47579.25       0
# 6821         59497.01       1
# 11           76390.01       0
# 355         160979.66       0
# ...               ...     ...
# 1462           236.45       1
# 4721        137136.29       0
# 9954          3449.22       0
# 445         183049.41       0
# 6619         23132.73       0
#
# [10000 rows x 14 columns]

# %%
df.sample(frac=0.5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 7518       7519    15779207    Nnamdi          500   Germany    Male   30
# 3333       3334    15599078      Yang          619   Germany  Female   41
# 8091       8092    15715510  Eluemuno          768    France    Male   29
# 1669       1670    15582259  Campbell          567    France  Female   37
# 1811       1812    15624068        Fu          779    France  Female   26
# ...         ...         ...       ...          ...       ...     ...  ...
# 7943       7944    15774250     Gallo          532    France    Male   42
# 1197       1198    15813444  McIntosh          590     Spain  Female   34
# 2796       2797    15770719    Duncan          697    France  Female   39
# 6108       6109    15761076       Lei          507    France    Male   41
# 1060       1061    15650933        Ma          490     Spain  Female   48
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7518       2  125495.64              2          1               1
# 3333       5   92467.58              1          1               0
# 8091       2   95984.69              2          1               1
# 1669       7       0.00              2          1               1
# 1811       0       0.00              2          0               1
# ...      ...        ...            ...        ...             ...
# 7943       1  159024.71              1          1               0
# 1197       6       0.00              2          1               0
# 2796       6  151553.19              1          1               1
# 6108       3   58820.32              2          1               1
# 1060       8  155413.06              1          1               0
#
#       EstimatedSalary  Exited
# 7518         68807.47       0
# 3333         38270.47       0
# 8091         73686.75       0
# 1669         28690.90       0
# 1811        111906.00       0
# ...               ...     ...
# 7943        100982.93       1
# 1197        171021.44       0
# 2796         44946.29       0
# 6108        138536.09       0
# 1060        187921.30       0
#
# [5000 rows x 14 columns]

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### Первичный анализ данных
# Переходим к аналитике, первым делом можно вывести сводную таблицу по типам данных, по количеству непропущенных объектов и по потреблению памяти в таблице через метод info().
# Типы данных:
# -	int: целочисленные значения. Пример: 9, 56, 30
# -	float: вещественные значения (с плавающей точкой). Пример: 7.3, 9.0, 45.334
# -	object/str: строковые значения. Пример: ‘hello, world’, ‘50 000’

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# ### Выводятся значения:
# 1.	Count - количество непропущенных объектов (там, где нет nan значений)
# 2.	mean - арифметическое среднее
# 3.	std - стандартное отклонение
# 4.	min - минимальное значение
# 5.	25% - квантиль 25 процентов
# 6.	50% - квантиль 50 процентов или же медиана
# 7.	75% - квантиль 75 процентов
# 8.	max - максимальное значение

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 92

# %%
df['Balance'].max()
# Out:
# 250898.09

# %%
df[['CreditScore','Age','Tenure']].mean()
# Out:
# CreditScore    650.5288
# Age             38.9218
# Tenure           5.0128
# dtype: float64

# %%
df.describe(include = ['object'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# ### Получаем 4 значения:
# 1.	count - количество непропущенных объектов
# 2.	unique - количество уникальных значений
# 3.	top - самое частотное значение (мода)
# 4.	freq - частота появления самого частотного значения

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'].astype('bool')
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Чтобы изменения вступили в силу нужно переопределить признак:

# %%
df['HasCrCard'].astype('bool')
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Geography'].value_counts(normalize=True)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %% [markdown]
# ### Фильтрация
# Булевая маска — бинарные данные, которые используются для выбора определенных объектов из структуры данных

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
male = df[df['Gender'] == 'Male']
male
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5          8  113755.78              2          1               0
# 6          7       0.00              2          1               1
# 8          4  142051.07              2          0               1
# 9          2  134603.88              1          1               1
# 10         6  102016.72              2          0               0
# ...      ...        ...            ...        ...             ...
# 9992       2       0.00              1          1               0
# 9993       7  155060.41              1          1               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9998       3   75075.31              2          1               0
#
#       EstimatedSalary  Exited
# 5           149756.71       1
# 6            10062.80       0
# 8            74940.50       0
# 9            71725.73       0
# 10           80181.12       0
# ...               ...     ...
# 9992        195192.40       0
# 9993         29179.52       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9998         92888.52       1
#
# [5457 rows x 14 columns]

# %% [markdown]
# ### Логическое И

# %%
df[(df['Gender'] == 'Female') & (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2             3    15619304           Onio          502    France  Female
# 7             8    15656148         Obinna          376   Germany  Female
# 30           31    15589475        Azikiwe          591     Spain  Female
# 88           89    15622897         Sharpe          646    France  Female
# 90           91    15757535           Heap          647     Spain  Female
# ...         ...         ...            ...          ...       ...     ...
# 9565       9566    15752294           Long          582    France  Female
# 9747       9748    15775761  Iweobiegbunam          610   Germany  Female
# 9800       9801    15640507             Li          762     Spain  Female
# 9877       9878    15572182     Onwuamaeze          505   Germany  Female
# 9895       9896    15796764          Bruno          684   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2      42       8  159660.80              3          1               0
# 7      29       4  115046.74              4          1               0
# 30     39       3       0.00              3          1               0
# 88     46       4       0.00              3          1               0
# 90     44       5       0.00              3          1               1
# ...   ...     ...        ...            ...        ...             ...
# 9565   38       9  135979.01              4          1               1
# 9747   69       5   86038.21              3          0               0
# 9800   35       3  119349.69              3          1               1
# 9877   33       3  106506.77              3          1               0
# 9895   56       3  127585.98              3          1               1
#
#       EstimatedSalary  Exited
# 2           113931.57       1
# 7           119346.88       1
# 30          140469.38       1
# 88           93251.42       1
# 90          174205.22       1
# ...               ...     ...
# 9565         76582.95       1
# 9747        192743.06       1
# 9800         47114.18       1
# 9877         45445.78       1
# 9895         80593.49       1
#
# [187 rows x 14 columns]

# %% [markdown]
# ### Логическое ИЛИ

# %%
df[(df['HasCrCard']) | (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 5             6    15574012        Chu          645     Spain    Male   44
# 6             7    15592531   Bartlett          822    France    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 2          8  159660.80              3          1               0
# 4          2  125510.82              1          1               1
# 5          8  113755.78              2          1               0
# 6          7       0.00              2          1               1
# ...      ...        ...            ...        ...             ...
# 9993       7  155060.41              1          1               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 2           113931.57       1
# 4            79084.10       0
# 5           149756.71       1
# 6            10062.80       0
# ...               ...     ...
# 9993         29179.52       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9998         92888.52       1
# 9999         38190.78       0
#
# [7150 rows x 14 columns]

# %% [markdown]
# ### Логическое НЕ

# %%
-(df['Geography'] == 'Spain')
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Name: Geography, Length: 10000, dtype: bool

# %%
df[df['Geography'].isin(['France','Germani'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 6          7       0.00              2          1               1
# 8          4  142051.07              2          0               1
# ...      ...        ...            ...        ...             ...
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 2           113931.57       1
# 3            93826.63       0
# 6            10062.80       0
# 8            74940.50       0
# ...               ...     ...
# 9994        167773.55       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9999         38190.78       0
#
# [5014 rows x 14 columns]

# %% [markdown]
# ### Индексация

# %%
df_small = df[(df['Geography'] == 'Spain')][['Geography', 'Gender', 'Age']]
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %% [markdown]
# ### loc

# %%
df_small.loc[1] # ключ индекс
# Out:
# Geography     Spain
# Gender       Female
# Age              41
# Name: 1, dtype: object

# %%
df_small.loc[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12832\3038161689.py in <module>
# ----> 1 df_small.loc[3]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
#    1204         self._validate_key(key, axis)
# -> 1205         return self._get_label(key, axis=axis)
#    1206
#    1207     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1151     def _get_label(self, label, axis: int):
#    1152         # GH#5667 this will fail if the label is not present in the axis.
# -> 1153         return self.obj.xs(label, axis=axis)
#    1154
#    1155     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3862                     new_index = index[loc]
#    3863         else:
# -> 3864             loc = index.get_loc(key)
#    3865
#    3866             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 3

# %% [markdown]
# ### iloc

# %%
df_small.iloc[[0, 1, 2]]
# Out:
#   Geography  Gender  Age
# 1     Spain  Female   41
# 4     Spain  Female   43
# 5     Spain    Male   44

# %%
df_small.iloc[2]
# Out:
# Geography    Spain
# Gender        Male
# Age             44
# Name: 5, dtype: object

# %%
df_small.iloc[0, [0, 2]]
# Out:
# Geography    Spain
# Age             41
# Name: 1, dtype: object

# %% [markdown]
# ### Сортировки

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 3512       3       0.00              2          1               1
# 1678       4   82767.42              1          1               0
# 3517       1       0.00              2          0               0
# 9520       2   93816.70              2          1               0
# 2021       3  128743.80              1          0               0
# ...      ...        ...            ...        ...             ...
# 3387       8   92242.34              1          1               1
# 3033      10       0.00              2          1               1
# 2458      10       0.00              2          1               1
# 6759       1  126076.24              2          1               1
# 6443       3  121513.31              1          0               1
#
#       EstimatedSalary  Exited
# 3512         86994.54       0
# 1678         71811.90       0
# 3517         41542.95       0
# 9520        126172.11       0
# 2021        197322.13       0
# ...               ...     ...
# 3387        186235.98       0
# 3033        116537.96       0
# 2458         52952.24       0
# 6759         34436.83       0
# 6443        195563.99       0
#
# [10000 rows x 14 columns]

# %%
df.sort_values('Age', ascending=False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6443       3  121513.31              1      False               1
# 6759       1  126076.24              2       True               1
# 2458      10       0.00              2       True               1
# 3033      10       0.00              2       True               1
# 3387       8   92242.34              1       True               1
# ...      ...        ...            ...        ...             ...
# 9782       7  102983.91              1       True               0
# 2141       7       0.00              2       True               1
# 9501       2  142872.36              1       True               1
# 9520       2   93816.70              2       True               0
# 1619      10  151762.74              1      False               1
#
#       EstimatedSalary  Exited
# 6443        195563.99       0
# 6759         34436.83       0
# 2458         52952.24       0
# 3033        116537.96       0
# 3387        186235.98       0
# ...               ...     ...
# 9782        171770.58       0
# 2141         55753.12       1
# 9501        117632.63       0
# 9520        126172.11       0
# 1619        127014.32       0
#
# [10000 rows x 14 columns]

# %%
df.sort_values(['Age', 'CreditScore'])
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9782       9783    15728829           Weigel          509    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9029       9030    15722701            Bruno          594   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 3387       3388    15798024             Lori          537   Germany    Male
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9782   18       7  102983.91              1       True               0
# 1678   18       4   82767.42              1       True               0
# 9029   18       1  132694.73              1       True               0
# 7334   18       6       0.00              2       True               1
# 9526   18       5  111183.53              2      False               1
# ...   ...     ...        ...            ...        ...             ...
# 3387   84       8   92242.34              1       True               1
# 3033   85      10       0.00              2       True               1
# 2458   88      10       0.00              2       True               1
# 6759   92       1  126076.24              2       True               1
# 6443   92       3  121513.31              1      False               1
#
#       EstimatedSalary  Exited
# 9782        171770.58       0
# 1678         71811.90       0
# 9029        167689.56       0
# 7334         27308.58       0
# 9526         10063.75       0
# ...               ...     ...
# 3387        186235.98       0
# 3033        116537.96       0
# 2458         52952.24       0
# 6759         34436.83       0
# 6443        195563.99       0
#
# [10000 rows x 14 columns]
