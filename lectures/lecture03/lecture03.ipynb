# %% [markdown]
# ###  Термины лекции
# Признак (англ.feature) — это индивидуальное свойство или характеристика объекта.
# Агрегация, или агрегирование — процесс объединения элементов в одно значение.

# %%
import pandas as pd

# %% [markdown]
# #### 1.	Работа с признаками
# a.	Создание признака

# %%
df = pd.read_csv('Churn_Modelling.csv')

users= df[['CustomerId','Surname','Geography','Gender','Age','EstimatedSalary']]
# df.to_csv'users.csv')]['Surname'
df
# user = pd.read_csv('users.csv')
# user
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
users = pd.read_csv('users.csv')
users
# Out:
#       Unnamed: 0  CustomerId    Surname Geography  Gender  Age  \
# 0              0    15634602   Hargrave    France  Female   42
# 1              1    15647311       Hill     Spain  Female   41
# 2              2    15619304       Onio    France  Female   42
# 3              3    15701354       Boni    France  Female   39
# 4              4    15737888   Mitchell     Spain  Female   43
# ...          ...         ...        ...       ...     ...  ...
# 9995        9995    15606229   Obijiaku    France    Male   39
# 9996        9996    15569892  Johnstone    France    Male   35
# 9997        9997    15584532        Liu    France  Female   36
# 9998        9998    15682355  Sabbatini   Germany    Male   42
# 9999        9999    15628319     Walker    France  Female   28
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 7 columns]

# %%
users['new_feature'] = 0
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    new_feature
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
users['Age (days)'] = users['Age'] * 365
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    new_feature  Age (days)
# 0            0       15330
# 1            0       14965
# 2            0       15330
# 3            0       14235
# 4            0       15695

# %% [markdown]
#  проход по циклу с помощью - iterrows

# %%
for i, row in users.iloc[:1].iterrows():
    print(row)
    print('++++++' * 10)
# Out:
# Unnamed: 0                 0
# CustomerId          15634602
# Surname             Hargrave
# Geography             France
# Gender                Female
# Age                       42
# EstimatedSalary    101348.88
# new_feature                0
# Age (days)             15330
# Name: 0, dtype: object
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# создаем лист и записываем в него данные

# %%
age_days = []

for i, row in users.iterrows():
    age_days.append(row['Age'] * 365)
    
age_days[:10]
# Out:
# [15330, 14965, 15330, 14235, 15695, 16060, 18250, 10585, 16060, 9855]

# %% [markdown]
# Записываем значения листа в новый признак

# %%
users['Age (days) 2'] = age_days
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    new_feature  Age (days)  Age (days) 2
# 0            0       15330         15330
# 1            0       14965         14965
# 2            0       15330         15330
# 3            0       14235         14235
# 4            0       15695         15695

# %% [markdown]
# создаем функцию и записываем через нее новые данные
# в pundas есть встроенный метод apply работает быстрее

# %%
def to_days(x):
    return x * 365

users['Applay (days)'] = users['Age'].apply(to_days)
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    new_feature  Age (days)  Age (days) 2  Applay (days)
# 0            0       15330         15330          15330
# 1            0       14965         14965          14965
# 2            0       15330         15330          15330
# 3            0       14235         14235          14235
# 4            0       15695         15695          15695

# %%
users['Age (days) lambda'] = users['Age'].apply(lambda x: x * 365)
users
# Out:
#       Unnamed: 0  CustomerId    Surname Geography  Gender  Age  \
# 0              0    15634602   Hargrave    France  Female   42
# 1              1    15647311       Hill     Spain  Female   41
# 2              2    15619304       Onio    France  Female   42
# 3              3    15701354       Boni    France  Female   39
# 4              4    15737888   Mitchell     Spain  Female   43
# ...          ...         ...        ...       ...     ...  ...
# 9995        9995    15606229   Obijiaku    France    Male   39
# 9996        9996    15569892  Johnstone    France    Male   35
# 9997        9997    15584532        Liu    France  Female   36
# 9998        9998    15682355  Sabbatini   Germany    Male   42
# 9999        9999    15628319     Walker    France  Female   28
#
#       EstimatedSalary  new_feature  Age (days)  Age (days) 2  Applay (days)  \
# 0           101348.88            0       15330         15330          15330
# 1           112542.58            0       14965         14965          14965
# 2           113931.57            0       15330         15330          15330
# 3            93826.63            0       14235         14235          14235
# 4            79084.10            0       15695         15695          15695
# ...               ...          ...         ...           ...            ...
# 9995         96270.64            0       14235         14235          14235
# 9996        101699.77            0       12775         12775          12775
# 9997         42085.58            0       13140         13140          13140
# 9998         92888.52            0       15330         15330          15330
# 9999         38190.78            0       10220         10220          10220
#
#       Age (days) lambda
# 0                 15330
# 1                 14965
# 2                 15330
# 3                 14235
# 4                 15695
# ...                 ...
# 9995              14235
# 9996              12775
# 9997              13140
# 9998              15330
# 9999              10220
#
# [10000 rows x 12 columns]

# %% [markdown]
# Библиотека tqdm - показывает прогресс бар

# %%
import time
from tqdm import tqdm
tqdm.pandas()

def age_to_days(x):
    time.sleep(0.01)
    return x * 356
users['Age (days) 3'] = users['Age'].progress_apply(age_to_days)
user.head()
# Out:
# 100%|████████████████████████████████████| 10000/10000 [02:35<00:00, 64.31it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14032\3198833586.py in <module>
#       7     return x * 356
#       8 users['Age (days) 3'] = users['Age'].progress_apply(age_to_days)
# ----> 9 user.head()
#
# NameError: name 'user' is not defined

# %% [markdown]
# ### b.	Удаление признака

# %%
users.drop(columns='new_feature')
users.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3172\2495679961.py in <module>
# ----> 1 users.drop(columns='new_feature')
#       2 users.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['new_feature'] not found in axis"

# %% [markdown]
# c.	Изменение признака

# %%
users['new_featury'] = 0
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    Age (days) lambda  Age (days)  Age (days) 2  Age (days) 3  new_featury
# 0              15330       15330         15330         14952            0
# 1              14965       14965         14965         14596            0
# 2              15330       15330         15330         14952            0
# 3              14235       14235         14235         13884            0
# 4              15695       15695         15695         15308            0

# %%
users = users.drop(columns='new_featury') # переопределение признака 
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    Age (days) lambda  Age (days)  Age (days) 2  Age (days) 3
# 0              15330       15330         15330         14952
# 1              14965       14965         14965         14596
# 2              15330       15330         15330         14952
# 3              14235       14235         14235         13884
# 4              15695       15695         15695         15308

# %%
users.drop(columns = 'Age (days)', inplace=True)
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    Age (days) lambda  Age (days) 2  Age (days) 3
# 0              15330         15330         14952
# 1              14965         14965         14596
# 2              15330         15330         14952
# 3              14235         14235         13884
# 4              15695         15695         15308

# %%
users.drop(columns=['Age (days) 2', 'Age (days) 3', 'Age (days) lambda'], inplace =True)
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10

# %% [markdown]
# ### .loc    - Чтобы изменить существующий признак пользуйтесь фильтрацией с помощью .loc

# %%
users['target'] = 0

# %%
users.loc[users['Geography'] == 'France']
# Out:
#       Unnamed: 0  CustomerId    Surname Geography  Gender  Age  \
# 0              0    15634602   Hargrave    France  Female   42
# 2              2    15619304       Onio    France  Female   42
# 3              3    15701354       Boni    France  Female   39
# 6              6    15592531   Bartlett    France    Male   50
# 8              8    15792365         He    France    Male   44
# ...          ...         ...        ...       ...     ...  ...
# 9994        9994    15719294       Wood    France  Female   29
# 9995        9995    15606229   Obijiaku    France    Male   39
# 9996        9996    15569892  Johnstone    France    Male   35
# 9997        9997    15584532        Liu    France  Female   36
# 9999        9999    15628319     Walker    France  Female   28
#
#       EstimatedSalary  target
# 0           101348.88       0
# 2           113931.57       0
# 3            93826.63       0
# 6            10062.80       0
# 8            74940.50       0
# ...               ...     ...
# 9994        167773.55       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       0
# 9999         38190.78       0
#
# [5014 rows x 8 columns]

# %%
users.loc[users['Geography'] == 'France', 'target']
# Out:
# 0       0
# 2       0
# 3       0
# 6       0
# 8       0
#        ..
# 9994    0
# 9995    0
# 9996    0
# 9997    0
# 9999    0
# Name: target, Length: 5014, dtype: int64

# %%
users[users['Geography'] == 'France']['target'] = 1 
users.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3172\3954258856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users[users['Geography'] == 'France']['target'] = 1
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
users.loc[users['Geography'] == 'France','target'] = 1 # переписывает первозданню таблицу
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography  Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France  Female   42        101348.88
# 1           1    15647311      Hill     Spain  Female   41        112542.58
# 2           2    15619304      Onio    France  Female   42        113931.57
# 3           3    15701354      Boni    France  Female   39         93826.63
# 4           4    15737888  Mitchell     Spain  Female   43         79084.10
#
#    target
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0

# %% [markdown]
# ### i.	.replace

# %%
users['Gender'].replace({'Female' : 'F', 'Male': 'M'}, inplace=True)
# инплайс меняет основныую таюлицу
users.head()
# Out:
#    Unnamed: 0  CustomerId   Surname Geography Gender  Age  EstimatedSalary  \
# 0           0    15634602  Hargrave    France      F   42        101348.88
# 1           1    15647311      Hill     Spain      F   41        112542.58
# 2           2    15619304      Onio    France      F   42        113931.57
# 3           3    15701354      Boni    France      F   39         93826.63
# 4           4    15737888  Mitchell     Spain      F   43         79084.10
#
#    target
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0

# %% [markdown]
# ## 2.	Методы агрегации
# Агрегация, или агрегирование — процесс объединения элементов в одно значение.

# %%
users['Age'].agg(['min', 'max']) # используется в Series
# Out:
# min    18
# max    92
# Name: Age, dtype: int64

# %%
users.agg({
    'Age': ['min', 'max'],
    'EstimatedSalary': 'mean' # заработная плата 
})
# Out:
#        Age  EstimatedSalary
# min   18.0              NaN
# max   92.0              NaN
# mean   NaN    100090.239881

# %%
users.agg(
    min_age = ('Age', 'min'),
    max_age = ('Age', 'max'),
    mean_salary = ('EstimatedSalary', 'mean')
)
# Out:
#               Age  EstimatedSalary
# min_age      18.0              NaN
# max_age      92.0              NaN
# mean_salary   NaN    100090.239881

# %% [markdown]
# ## 3.	Методы объединения

# %% [markdown]
# ### a.	Метод merge

# %%
bank = df[['CustomerId','CreditScore','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','Exited']]
bank
bank.to_csv('bank.csv')

# %%
bank = pd.read_csv('bank.csv')
bank
# Out:
#       Unnamed: 0  CustomerId  CreditScore  Tenure    Balance  NumOfProducts  \
# 0              0    15634602          619       2       0.00              1
# 1              1    15647311          608       1   83807.86              1
# 2              2    15619304          502       8  159660.80              3
# 3              3    15701354          699       1       0.00              2
# 4              4    15737888          850       2  125510.82              1
# ...          ...         ...          ...     ...        ...            ...
# 9995        9995    15606229          771       5       0.00              2
# 9996        9996    15569892          516      10   57369.61              1
# 9997        9997    15584532          709       7       0.00              1
# 9998        9998    15682355          772       3   75075.31              2
# 9999        9999    15628319          792       4  130142.79              1
#
#       HasCrCard  IsActiveMember  Exited
# 0             1               1       1
# 1             0               1       0
# 2             1               0       1
# 3             0               0       0
# 4             1               1       0
# ...         ...             ...     ...
# 9995          1               0       0
# 9996          1               1       0
# 9997          0               1       1
# 9998          1               0       1
# 9999          1               0       0
#
# [10000 rows x 9 columns]

# %%
bank.shape
# Out:
# (10000, 9)

# %%
merged = users.merge(bank, left_on='CustomerId', right_on='CustomerId')
merged.head()
# Out:
#    CustomerId   Surname Geography  Gender  Age  EstimatedSalary  Unnamed: 0  \
# 0    15634602  Hargrave    France  Female   42        101348.88           0
# 1    15647311      Hill     Spain  Female   41        112542.58           1
# 2    15619304      Onio    France  Female   42        113931.57           2
# 3    15701354      Boni    France  Female   39         93826.63           3
# 4    15737888  Mitchell     Spain  Female   43         79084.10           4
#
#    CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          619       2       0.00              1          1               1
# 1          608       1   83807.86              1          0               1
# 2          502       8  159660.80              3          1               0
# 3          699       1       0.00              2          0               0
# 4          850       2  125510.82              1          1               1
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# b.	Метод join

# %%
users_id = users.set_index('CustomerId')
users_id.head()
# Out:
#              Surname Geography  Gender  Age  EstimatedSalary
# CustomerId
# 15634602    Hargrave    France  Female   42        101348.88
# 15647311        Hill     Spain  Female   41        112542.58
# 15619304        Onio    France  Female   42        113931.57
# 15701354        Boni    France  Female   39         93826.63
# 15737888    Mitchell     Spain  Female   43         79084.10

# %%
bank_id = bank.set_index('CustomerId')
bank_id.head()
# Out:
#             Unnamed: 0  CreditScore  Tenure    Balance  NumOfProducts  \
# CustomerId
# 15634602             0          619       2       0.00              1
# 15647311             1          608       1   83807.86              1
# 15619304             2          502       8  159660.80              3
# 15701354             3          699       1       0.00              2
# 15737888             4          850       2  125510.82              1
#
#             HasCrCard  IsActiveMember  Exited
# CustomerId
# 15634602            1               1       1
# 15647311            0               1       0
# 15619304            1               0       1
# 15701354            0               0       0
# 15737888            1               1       0

# %%
bank_id.join(users_id).head()
# Out:
#             Unnamed: 0  CreditScore  Tenure    Balance  NumOfProducts  \
# CustomerId
# 15634602             0          619       2       0.00              1
# 15647311             1          608       1   83807.86              1
# 15619304             2          502       8  159660.80              3
# 15701354             3          699       1       0.00              2
# 15737888             4          850       2  125510.82              1
#
#             HasCrCard  IsActiveMember  Exited   Surname Geography  Gender  \
# CustomerId
# 15634602            1               1       1  Hargrave    France  Female
# 15647311            0               1       0      Hill     Spain  Female
# 15619304            1               0       1      Onio    France  Female
# 15701354            0               0       0      Boni    France  Female
# 15737888            1               1       0  Mitchell     Spain  Female
#
#             Age  EstimatedSalary
# CustomerId
# 15634602     42        101348.88
# 15647311     41        112542.58
# 15619304     42        113931.57
# 15701354     39         93826.63
# 15737888     43         79084.10

# %% [markdown]
# #### Чтобы вытащить уникальные идентификаторы пользователей из индексов можно вызвать атрибут reset_index():

# %%
bank_id.join(users_id).reset_index().head()
# Out:
#    CustomerId  Unnamed: 0  CreditScore  Tenure    Balance  NumOfProducts  \
# 0    15634602           0          619       2       0.00              1
# 1    15647311           1          608       1   83807.86              1
# 2    15619304           2          502       8  159660.80              3
# 3    15701354           3          699       1       0.00              2
# 4    15737888           4          850       2  125510.82              1
#
#    HasCrCard  IsActiveMember  Exited   Surname Geography  Gender  Age  \
# 0          1               1       1  Hargrave    France  Female   42
# 1          0               1       0      Hill     Spain  Female   41
# 2          1               0       1      Onio    France  Female   42
# 3          0               0       0      Boni    France  Female   39
# 4          1               1       0  Mitchell     Spain  Female   43
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
bank.shape[0]
# Out:
# 10000

# %% [markdown]
# #### c.	Атрибут how

# %%
toy_df1 = pd.DataFrame({
    'col_1' : [1 ,2 ,3], 
    'col_2' : [9, 9, 9]
})
toy_df1
# Out:
#    col_1  col_2
# 0      1      9
# 1      2      9
# 2      3      9

# %%
toy_df2 = pd.DataFrame({
    'col_1': [3, 4],
    'col_3': [0, 0]
})
toy_df2
# Out:
#    col_1  col_3
# 0      3      0
# 1      4      0

# %% [markdown]
# ### -	left - остаются все объекты с левого датафрейма и ищутся совпадения из правого

# %%
toy_df1.merge(toy_df2, how='left')
# Out:
#    col_1  col_2  col_3
# 0      1      9    NaN
# 1      2      9    NaN
# 2      3      9    0.0

# %%
merged_left_b = bank.merge(users, on="CustomerId", how='left')
merged_left_b.head()
# Out:
#    Unnamed: 0  CustomerId  CreditScore  Tenure    Balance  NumOfProducts  \
# 0           0    15634602          619       2       0.00              1
# 1           1    15647311          608       1   83807.86              1
# 2           2    15619304          502       8  159660.80              3
# 3           3    15701354          699       1       0.00              2
# 4           4    15737888          850       2  125510.82              1
#
#    HasCrCard  IsActiveMember  Exited   Surname Geography  Gender  Age  \
# 0          1               1       1  Hargrave    France  Female   42
# 1          0               1       0      Hill     Spain  Female   41
# 2          1               0       1      Onio    France  Female   42
# 3          0               0       0      Boni    France  Female   39
# 4          1               1       0  Mitchell     Spain  Female   43
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
merged_left_b.isna().sum()
# Out:
# Unnamed: 0         0
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# dtype: int64

# %%
merged_left_b[merged_left_b['Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CustomerId, CreditScore, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, Exited, Surname, Geography, Gender, Age, EstimatedSalary]
# Index: []

# %%
users[users['CustomerId'] == 15682355]
# Out:
#       CustomerId    Surname Geography Gender  Age  EstimatedSalary
# 9998    15682355  Sabbatini   Germany   Male   42         92888.52

# %% [markdown]
# ### -	right - остаются все объекты с правого датафрейма и ищутся совпадения из левого

# %%
merged_rigth= bank.merge(users, on='CustomerId', how='right')
merged_rigth
# Out:
#       Unnamed: 0  CustomerId  CreditScore  Tenure    Balance  NumOfProducts  \
# 0              0    15634602          619       2       0.00              1
# 1              1    15647311          608       1   83807.86              1
# 2              2    15619304          502       8  159660.80              3
# 3              3    15701354          699       1       0.00              2
# 4              4    15737888          850       2  125510.82              1
# ...          ...         ...          ...     ...        ...            ...
# 9995        9995    15606229          771       5       0.00              2
# 9996        9996    15569892          516      10   57369.61              1
# 9997        9997    15584532          709       7       0.00              1
# 9998        9998    15682355          772       3   75075.31              2
# 9999        9999    15628319          792       4  130142.79              1
#
#       HasCrCard  IsActiveMember  Exited    Surname Geography  Gender  Age  \
# 0             1               1       1   Hargrave    France  Female   42
# 1             0               1       0       Hill     Spain  Female   41
# 2             1               0       1       Onio    France  Female   42
# 3             0               0       0       Boni    France  Female   39
# 4             1               1       0   Mitchell     Spain  Female   43
# ...         ...             ...     ...        ...       ...     ...  ...
# 9995          1               0       0   Obijiaku    France    Male   39
# 9996          1               1       0  Johnstone    France    Male   35
# 9997          0               1       1        Liu    France  Female   36
# 9998          1               0       1  Sabbatini   Germany    Male   42
# 9999          1               0       0     Walker    France  Female   28
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 14 columns]

# %%
merged_rigth.isna().sum()
# Out:
# Unnamed: 0         0
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# dtype: int64

# %%
merged_rigth[merged_rigth['CreditScore'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, CustomerId, CreditScore, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, Exited, Surname, Geography, Gender, Age, EstimatedSalary]
# Index: []

# %%
bank[bank['CustomerId'] == 15634602]
# Out:
#    Unnamed: 0  CustomerId  CreditScore  Tenure  Balance  NumOfProducts  \
# 0           0    15634602          619       2      0.0              1
#
#    HasCrCard  IsActiveMember  Exited
# 0          1               1       1

# %%
toy_df1.merge(toy_df2, how='right')
# Out:
#    col_1  col_2  col_3
# 0      3    9.0      0
# 1      4    NaN      0

# %% [markdown]
# ### -	inner - остаются объекты, которые есть и в левом датафрейме, и в правом

# %%
merged_inner = bank.merge(users, on="CustomerId", how='inner')
merged_inner.shape[0]
# Out:
# 10000

# %%
merged_inner.isna().sum()
# Out:
# Unnamed: 0         0
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# dtype: int64

# %%
toy_df1.merge(toy_df2, how='inner')
# Out:
#    col_1  col_2  col_3
# 0      3      9      0

# %% [markdown]
# ### -	outer - остаются все объекты из двуз датафреймов

# %%
merged_outer = bank.merge(users, on='CustomerId', how = 'outer')
merged_outer.shape[0]
# Out:
# 10000

# %%
merged_outer.isna().sum()
# Out:
# Unnamed: 0         0
# CustomerId         0
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# Age                0
# EstimatedSalary    0
# dtype: int64

# %%
toy_df1.merge(toy_df2, how='outer')
# Out:
#    col_1  col_2  col_3
# 0      1    9.0    NaN
# 1      2    9.0    NaN
# 2      3    9.0    0.0
# 3      4    NaN    0.0

# %% [markdown]
# ### 4.	Методы группировки

# %% [markdown]
# #### a.	groupby

# %%
toy_df = pd.DataFrame({
    'client_id': [1, 2, 2, 3, 1, 1],
    'item': ['chocolate', 'cheese', 'ham', 'candy', 'chair', 'book'],
    'price': [68, 280, 302, 39, 2099, 1089]
})
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
grouped = toy_df.groupby('client_id')
grouped

# %%
grouped.groups
# Out:
# {1: [0, 4, 5], 2: [1, 2], 3: [3]}

# %%
grouped.sum()
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
grouped.agg({'price': ['sum','min','max']})
# Out:
#           price
#             sum  min   max
# client_id
# 1          3256   68  2099
# 2           582  280   302
# 3            39   39    39

# %%
users.groupby('Geography').agg({'Age': ['mean'], 'EstimatedSalary': ['min']})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %% [markdown]
# #### b.	pivot_table
# Параметры pivot_table():
# -	index – столбец, который будет использован для строк
# -	columns – столбец, который будет использован для столбцов
# -	values – столбец обрабатываемых значений
# -	aggfunc – функция, применяемая к values
# -	fill_value – значение по умолчанию
# -	margins – если True, то добавляется столбец All (Итого). По умолчанию: False

# %%
toy_df.pivot_table(index='client_id',
                  values='price',
                  aggfunc='sum'
                  )
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
users.pivot_table(index='Geography',
                 aggfunc={'Age': ['mean'],'EstimatedSalary': 'min'})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
users.pivot_table(index='Geography',
                  columns='Gender',
                  values='EstimatedSalary',
                  aggfunc='mean',
                  margins=True,
                  margins_name = 'Total'
                 )
# Out:
# Gender            Female           Male          Total
# Geography
# France      99564.252755  100174.252495   99899.180814
# Germany    102446.424124   99905.033959  101113.435102
# Spain      100734.107475   98425.687680   99440.572281
# Total      100601.541382   99664.576931  100090.239881

# %% [markdown]
# #### c.	crosstab

# %%
pd.crosstab(index= users['Geography'],
           columns=users['Gender'])
# Out:
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388

# %%
pd.crosstab(index= users['Geography'],
           columns=users['Gender'],
           values= users['EstimatedSalary'],
           aggfunc= 'mean')
# Out:
# Gender            Female           Male
# Geography
# France      99564.252755  100174.252495
# Germany    102446.424124   99905.033959
# Spain      100734.107475   98425.687680

# %%
pd.crosstab(index= users['Geography'],
           columns=users['Gender'],
            normalize='all')
# Out:
# Gender     Female    Male
# Geography
# France     0.2261  0.2753
# Germany    0.1193  0.1316
# Spain      0.1089  0.1388

# %%
pd.crosstab(index= users['Geography'],
           columns=users['Gender'],
            normalize='index')
# Out:
# Gender       Female      Male
# Geography
# France     0.450937  0.549063
# Germany    0.475488  0.524512
# Spain      0.439645  0.560355

# %%
pd.crosstab(index= users['Geography'],
           columns=users['Gender'],
            normalize= 'columns')
# Out:
# Gender       Female      Male
# Geography
# France     0.497689  0.504490
# Germany    0.262602  0.241158
# Spain      0.239709  0.254352

# %% [markdown]
# ### 5.	Встроенные визуализации

# %% [markdown]
# 1.	hist() - гистограмма. С помощью неё можем изучить распределение возраста наших клиентов:

# %%
users['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 2.	pie() - круговая диаграмма, с помощью неё поизучаем долю мужчин и долю женщин среди наших клиентов:

# %%
data = users.groupby('Gender').count()['Age']
data.name = 'Gender'
data
# Out:
# Gender
# Female    4543
# Male      5457
# Name: Gender, dtype: int64

# %%
data.plot.pie(y= 'Gender')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# ### 3.	 scatter() - точечный график, он показывает взаимное распределение признаков.

# %%
users.iloc[:100].plot.scatter(x = 'Age', y = 'EstimatedSalary')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# ### 4.	 bar() - столбчатая диаграмма, показывает количество объектов в каждой категории.

# %%
data = bank.groupby('Tenure').count()['Balance']
data.name = 'num_clients'
data
# Out:
# Tenure
# 0      413
# 1     1035
# 2     1048
# 3     1009
# 4      989
# 5     1012
# 6      967
# 7     1028
# 8     1025
# 9      984
# 10     490
# Name: num_clients, dtype: int64

# %%
data.plot.bar( width = 0.8)
# Out:
# <AxesSubplot:xlabel='Tenure'>
